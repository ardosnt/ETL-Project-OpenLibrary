# %%
from extract import request_openlibrary
import pandas as pd

# %%
raw_data = request_openlibrary("subjects", "cinema")
df_raw = pd.DataFrame(raw_data.get("works", []))
# Out:
# Dados extraídos com sucesso!

# %% [markdown]
# ### Transform/Clean

# %%
print(f"Quantidade de registros:{len(df_raw)}")
print(f"Quantidade de colunas:{len(df_raw.columns)}")
df_raw.info()
df_raw
# Out:
# Quantidade de registros:12
# Quantidade de colunas:16
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   key                 12 non-null     str
#  1   title               12 non-null     str
#  2   edition_count       12 non-null     int64
#  3   cover_id            11 non-null     float64
#  4   cover_edition_key   9 non-null      str
#  5   subject             12 non-null     object
#  6   ia_collection       12 non-null     object
#  7   printdisabled       12 non-null     bool
#  8   lending_edition     12 non-null     str
#  9   lending_identifier  12 non-null     str
#  10  authors             12 non-null     object
#  11  first_publish_year  12 non-null     int64
#  12  ia                  10 non-null     str
#  13  public_scan         12 non-null     bool
#  14  has_fulltext        12 non-null     bool
#  15  availability        10 non-null     object
# dtypes: bool(3), float64(1), int64(2), object(4), str(6)
# memory usage: 1.4+ KB
#                    key                      title  edition_count    cover_id  \
# 0   /works/OL15719630W                  Divergent             87  13274634.0
# 1    /works/OL8101202W               Film Studies             24   1218567.0
# 2    /works/OL2030265W                Tacita Dean             19   2249492.0
# 3     /works/OL550723W       Understanding movies             18     88910.0
# 4    /works/OL1632964W                     Kitsch             16   7283834.0
# 5    /works/OL5745510W                  Lucky man             15    227135.0
# 6    /works/OL4031817W      Looking for Alibrandi             13    658487.0
# 7    /works/OL3295091W    British national cinema             12   4968848.0
# 8   /works/OL18257790W    Psychoanalysis & cinema              9   1221176.0
# 9    /works/OL1644934W           Producing Videos              9   2071096.0
# 10  /works/OL15837167W          I'll Cry Tomorrow              9   6724290.0
# 11   /works/OL5278932W  The decline of the cinema              9         NaN
#
#    cover_edition_key                                            subject  \
# 0        OL26223598M  [New York Times bestseller, nyt:paperback_book...
# 1         OL7493068M  [Motion pictures, Film criticism, Motion pictu...
# 2         OL8987267M  [Cinematography, Abstract, Performance art, Ex...
# 3                NaN  [Motion pictures, Textbooks, Aesthetics, Analy...
# 4                NaN  [architecture, art, camp, bio-pics, design, fi...
# 5         OL3952636M  [Parkinson's Disease, Biographies, Parkinsonie...
# 6         OL6893861M  [Juvenile fiction, Catholic schools, Fiction, ...
# 7         OL9368124M  [History, Motion pictures, Motion picture indu...
# 8         OL2188158M  [Psychoanalysis and motion pictures, Psychoana...
# 9         OL8648468M  [Production and direction, Video recordings, V...
# 10       OL14575908M  [Lillian Roth, 1910-1980, Mike Connolly, Gerol...
# 11               NaN  [Motion picture industry, Motion picture theat...
#
#                                         ia_collection  printdisabled  \
# 0   [delawarecountydistrictlibrary-ol, georgetown-...           True
# 1   [dartmouthlibrary-ol, gwulibraries-ol, interne...           True
# 2                                                  []          False
# 3               [internetarchivebooks, printdisabled]           True
# 4    [inlibrary, internetarchivebooks, printdisabled]           True
# 5   [americana, delawarecountydistrictlibrary, int...           True
# 6               [internetarchivebooks, printdisabled]           True
# 7               [internetarchivebooks, printdisabled]           True
# 8   [binghamton-ol, dartmouthlibrary-ol, drakeuniv...           True
# 9                                                  []          False
# 10   [inlibrary, internetarchivebooks, printdisabled]           True
# 11                                                 []          False
#
#    lending_edition        lending_identifier  \
# 0      OL47748336M        1divergent0000vero
# 1
# 2
# 3
# 4       OL4753714M  kitschworldofbad0000dorf
# 5
# 6
# 7
# 8
# 9
# 10     OL14575908M      illcrytomorrow00roth
# 11
#
#                                               authors  first_publish_year  \
# 0   [{'key': '/authors/OL6895646A', 'name': 'Veron...                2010
# 1   [{'key': '/authors/OL2698167A', 'name': 'Amy V...                2006
# 2   [{'key': '/authors/OL245385A', 'name': 'Tacita...                1998
# 3   [{'key': '/authors/OL39207A', 'name': 'Louis D...                1972
# 4   [{'key': '/authors/OL181580A', 'name': 'Gillo ...                1969
# 5   [{'key': '/authors/OL1397529A', 'name': 'Micha...                1998
# 6   [{'key': '/authors/OL747137A', 'name': 'Melina...                1992
# 7   [{'key': '/authors/OL538969A', 'name': 'Sarah ...                1997
# 8   [{'key': '/authors/OL537805A', 'name': 'E. Ann...                1990
# 9   [{'key': '/authors/OL183510A', 'name': 'Martha...                1997
# 10  [{'key': '/authors/OL1662200A', 'name': 'Lilli...                1954
# 11  [{'key': '/authors/OL1195293A', 'name': 'John ...                1962
#
#                           ia  public_scan  has_fulltext  \
# 0         1divergent0000vero        False          True
# 1        filmstudies0000vill        False          True
# 2                        NaN        False         False
# 3   understandingmov00gian_1        False          True
# 4   kitschworldofbad0000dorf        False          True
# 5             luckyman00mich        False          True
# 6   lookingforalibra0000marc        False          True
# 7   britishnationalc0000stre        False          True
# 8   psychoanalysisci0000unse        False          True
# 9     producingvideosc00moll        False         False
# 10      illcrytomorrow00roth        False          True
# 11                       NaN        False         False
#
#                                          availability
# 0   {'status': 'borrow_available', 'available_to_b...
# 1   {'status': 'private', 'available_to_browse': F...
# 2                                                 NaN
# 3   {'status': 'private', 'available_to_browse': F...
# 4   {'status': 'borrow_available', 'available_to_b...
# 5   {'status': 'private', 'available_to_browse': F...
# 6   {'status': 'private', 'available_to_browse': F...
# 7   {'status': 'private', 'available_to_browse': F...
# 8   {'status': 'private', 'available_to_browse': F...
# 9   {'status': 'error', 'error_message': 'not foun...
# 10  {'status': 'borrow_available', 'available_to_b...
# 11                                                NaN

# %%
#Filtrando colunas
cols = ['key', 'title', 'first_publish_year', 'edition_count', 'authors']
df = df_raw[cols]

#Filtrando nome real do autor e dropando tabela antiga
df['author_name'] = df['authors'].apply(lambda x: x[0]['name'] if isinstance(x, list) and len(x) > 0 else None)
df = df.drop(columns=["authors"])

#Limpando a key
df['key'] = df['key'].str.replace('/works/', '', regex=False)

# %%
df
# Out:
#             key                      title  first_publish_year  edition_count  \
# 0   OL15719630W                  Divergent                2010             87
# 1    OL8101202W               Film Studies                2006             24
# 2    OL2030265W                Tacita Dean                1998             19
# 3     OL550723W       Understanding movies                1972             18
# 4    OL1632964W                     Kitsch                1969             16
# 5    OL5745510W                  Lucky man                1998             15
# 6    OL4031817W      Looking for Alibrandi                1992             13
# 7    OL3295091W    British national cinema                1997             12
# 8   OL18257790W    Psychoanalysis & cinema                1990              9
# 9    OL1644934W           Producing Videos                1997              9
# 10  OL15837167W          I'll Cry Tomorrow                1954              9
# 11   OL5278932W  The decline of the cinema                1962              9
#
#            author_name
# 0        Veronica Roth
# 1        Amy Villarejo
# 2          Tacita Dean
# 3   Louis D. Giannetti
# 4        Gillo Dorfles
# 5       Michael J. Fox
# 6     Melina Marchetta
# 7         Sarah Street
# 8        E. Ann Kaplan
# 9      Martha Mollison
# 10        Lillian Roth
# 11         John Spraos
